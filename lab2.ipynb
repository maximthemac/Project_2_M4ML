# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier


# Load the data
df = pd.read_csv('/Users/maximlamoureux/Downloads/Acoustic Features.csv')
X = df.iloc[:, 1:51]
y = df.iloc[:,0]

# split the data into training and testing sets with equal number of samples from each class
X_train, X_test, y_train, y_test = sk.model_selection.train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)

# %%
# PRIMARY DATA EXPLORATION

# the ten most important features

model = ExtraTreesClassifier()
model.fit(X, y)
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
